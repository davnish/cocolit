# %%
import pandas as pd
import rasterio as rio
import geopandas as gpd
from pathlib import Path
from rasvec import tms_to_geotiff
from rasvec import patchify_raster

# %% [markdown]
# # Reading vector data

# %%
vec_path = Path("../data/raw/vector/prediction_3857.shp")
gdf = gpd.read_file(vec_path).to_crs("EPSG:4326")
bounds = gdf.total_bounds
bounds
# Out:
# array([79.84896457,  8.1853809 , 79.90514314,  8.20419389])

# %% [markdown]
# # Downloading vector data

# %%
ras_path = "../data/raw/raster/prediction_3857.tif"

# %%
tms_to_geotiff(
    output=ras_path, bbox=bounds.tolist(), source="satellite", zoom=19, overwrite=True
)
# Out:
# Downloaded image 0001/2407
# Downloaded image 0002/2407
# Downloaded image 0003/2407
# Downloaded image 0004/2407
# Downloaded image 0005/2407
# Downloaded image 0006/2407
# Downloaded image 0007/2407
# Downloaded image 0008/2407
# Downloaded image 0009/2407
# Downloaded image 0010/2407
# Downloaded image 0011/2407
# Downloaded image 0012/2407
# Downloaded image 0013/2407
# Downloaded image 0014/2407
# Downloaded image 0015/2407
# Downloaded image 0016/2407
# Downloaded image 0017/2407
# Downloaded image 0018/2407
# Downloaded image 0019/2407
# Downloaded image 0020/2407
# Downloaded image 0021/2407
# Downloaded image 0022/2407
# Downloaded image 0023/2407
# Downloaded image 0024/2407
# Downloaded image 0025/2407
# Downloaded image 0026/2407
# Downloaded image 0027/2407
# Downloaded image 0028/2407
# Downloaded image 0029/2407
# Downloaded image 0030/2407
# Downloaded image 0031/2407
# Downloaded image 0032/2407
# Downloaded image 0033/2407
# Downloaded image 0034/2407
# Downloaded image 0035/2407
# Downloaded image 0036/2407
# Downloaded image 0037/2407
# Downloaded image 0038/2407
# Downloaded image 0039/2407
# Downloaded image 0040/2407
# Downloaded image 0041/2407
# Downloaded image 0042/2407
# Downloaded image 0043/2407
# Downloaded image 0044/2407
# Downloaded image 0045/2407
# Downloaded image 0046/2407
# Downloaded image 0047/2407
# Downloaded image 0048/2407
# Downloaded image 0049/2407
# Downloaded image 0050/2407
# Downloaded image 0051/2407
# Downloaded image 0052/2407
# Downloaded image 0053/2407
# Downloaded image 0054/2407
# Downloaded image 0055/2407
# Downloaded image 0056/2407
# Downloaded image 0057/2407
# Downloaded image 0058/2407
# Downloaded image 0059/2407
# Downloaded image 0060/2407
# Downloaded image 0061/2407
# Downloaded image 0062/2407
# Downloaded image 0063/2407
# Downloaded image 0064/2407
# Downloaded image 0065/2407
# Downloaded image 0066/2407
# Downloaded image 0067/2407
# Downloaded image 0068/2407
# Downloaded image 0069/2407
# Downloaded image 0070/2407
# Downloaded image 0071/2407
# Downloaded image 0072/2407
# Downloaded image 0073/2407
# Downloaded image 0074/2407
# Downloaded image 0075/2407
# Downloaded image 0076/2407
# Downloaded image 0077/2407
# Downloaded image 0078/2407
# Downloaded image 0079/2407
# Downloaded image 0080/2407
# Downloaded image 0081/2407
# Downloaded image 0082/2407
# Downloaded image 0083/2407
# Downloaded image 0084/2407
# Downloaded image 0085/2407
# Downloaded image 2395/2407
# Downloaded image 2396/2407
# Downloaded image 2397/2407
# Downloaded image 2398/2407
# Downloaded image 2399/2407
# Downloaded image 2400/2407
# Downloaded image 2401/2407
# Downloaded image 2402/2407
# Downloaded image 2403/2407
# Downloaded image 2404/2407
# Downloaded image 2405/2407
# Downloaded image 2406/2407
# Downloaded image 2407/2407
# Saving GeoTIFF. Please wait...
# Image saved to ../data/raw/raster/prediction_3857.tif

# %% [markdown]
# # Patching the raster

# %%
output_patched_ras = Path("../data/raw/patched_ras")

# %%
patchify_raster(ras_path, output_path=output_patched_ras, patch_size=640, padding=True)
# Out:
# Patches shape: (12, 33, 640, 640, 3)
# Saved the patched files in output dir: ../data/raw/patched_ras

# %% [markdown]
# # Patching Vector

# %%
from rasvec import clip_vector_by_raster

# %%
output_patched_vec = Path("../data/raw/patched_vec")

# %%
for i in Path(output_patched_ras).glob("*.tif"):
    filepath = i.parents[1] / "patched_vec" / (i.stem + ".shp")
    shp_clipped = clip_vector_by_raster(i, vec_path, filepath)

# %% [markdown]
# # Vector to txt

# %%
def vec_to_txt_add_bbox(ras_path, vec_path, output_path):
    """Convert the shapefile to text with adding attributes of the bbox.
    All the attributes of the bbox are calculated with respect to raster's top left corner.
    The bbox is the bounding box of the vector file.
    the attributes are:
    - distx: distance in the x direction of the bbox from the
    - disty: distance in the y direction of the bbox from the
    - width: width of the bbox.
    - height: height of the bbox.

    Args:
        ras_path (str): path to the raster file.
        vec_path (str): path to the vector file.
        output_path (str): path of the directory of the output txt file.
    """

    ras_path = Path(ras_path)
    vec_path = Path(vec_path)
    output_path = Path(output_path)
    with rio.open(ras_path) as src:
        ras_bounds = src.bounds
        top_left_corner = (ras_bounds.left, ras_bounds.top)
        botton_right_corner = (ras_bounds.right, ras_bounds.bottom)

    vector = gpd.read_file(vec_path).to_crs("EPSG:3857")
    distx = []
    disty = []
    width = []
    height = []
    for feature in vector["geometry"]:
        try:
            if feature is not None:
                distx.append(
                    abs(feature.x - top_left_corner[0])
                    / abs(top_left_corner[0] - botton_right_corner[0])
                )
                disty.append(
                    abs(feature.y - top_left_corner[1])
                    / abs(top_left_corner[1] - botton_right_corner[1])
                )
                width.append(5 / abs(botton_right_corner[0] - top_left_corner[0]))
                height.append(5 / abs(botton_right_corner[1] - top_left_corner[1]))

        except Exception as e:
            print(e)
            continue

    df = pd.DataFrame(
        {"class": 0, "distx": distx, "disty": disty, "width": width, "height": height}
    )
    df.to_csv(output_path / (ras_path.stem + ".txt"), index=False, sep=" ", header=None)

# %%
output_patched_txt = Path("../data/raw/patched_txt")

# %%
for i in Path(output_patched_ras).glob("*.tif"):
    vec_path = i.parents[1] / "patched_vec" / (i.stem + ".shp")
    vec_to_txt_add_bbox(
        i,
        vec_path,
    )

# %% [markdown]
# #  train_test_val_split

# %%
import glob
import os
import random
import shutil

random.seed(42)


def shuffle_data(data_list):
    random.shuffle(data_list)
    return data_list


def get_label_path(img_path):
    filename = os.path.basename(img_path)
    label_path = os.path.split(os.path.split(img_path)[0])[0] + rf"\label\{filename}"
    return label_path


def train_test_split(
    images: Path | list,
    labels: Path | list,
    train_size: float,
    split_path: Path | None = None,
):
    """This split the dataset whcih consist of data and label into training and testing set.
        Note: This wont work if there are mutiple directories inside data_path or label_path
    Args:
        images (str): Path consisting the data.
        labels (str): Path consisting the labels.
        train_size (float): Ratio of the train_size. Range from 0 - 1.
        split_path (str, optional): If this is provided the data and label and splited and transfered to this directory.
                                    Defaults to None.

    Returns:
        list (str): training_data, training_label, testing_data, testing_label.
    """

    if isinstance(images, Path):
        img_list = [i for i in images.glob("*.tif")]
    elif isinstance(images, list):
        img_list = images

    label_list = [labels / (i.stem + ".txt") for i in img_list]

    img_list = shuffle_data(img_list)

    train_size = int(len(img_list) * train_size)
    trainx = img_list[:train_size]
    trainy = label_list[:train_size]
    testx = img_list[train_size:]
    testy = label_list[train_size:]

    print(f"Train Size: {train_size}, Test Size: {len(img_list) - train_size}")
    return trainx, trainy, testx, testy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 19
#      15     label_path = os.path.split(os.path.split(img_path)[0])[0] + rf"\label\{filename}"
#      16     return label_path
# ---> 19 def train_test_split(images : Path | list, labels : Path | list, train_size : float, split_path : Path | None = None):
#      20     """This split the dataset whcih consist of data and label into training and testing set.
#      21         Note: This wont work if there are mutiple directories inside data_path or label_path
#      22     Args:
#    (...)     30         list (str): training_data, training_label, testing_data, testing_label.
#      31     """
#      33     if isinstance(images, Path):
#
# NameError: name 'Path' is not defined

# %%
trainx, trainy, testx, testy = train_test_split(
    output_patched_ras, output_patched_txt, 0.8
)
valx, valy, testx, testy = train_test_split(testx, output_patched_txt, 0.5)
# train_test_split(output_patched_ras, output_patched_vec, 0.8, split_path = None)
# Out:
# Train Size: 316, Test Size: 80
# Train Size: 40, Test Size: 40

# %%
trainx_path = Path("../data/train/images")
trainy_path = Path("../data/train/labels")
testx_path = Path("../data/test/images")
testy_path = Path("../data/test/labels")
valx_path = Path("../data/val/images")
valy_path = Path("../data/val/labels")

trainx_path.mkdir(parents=True, exist_ok=True)
trainy_path.mkdir(parents=True, exist_ok=True)
testx_path.mkdir(parents=True, exist_ok=True)
testy_path.mkdir(parents=True, exist_ok=True)

for file in trainx:
    if (trainx_path / file.name).exists():
        continue
    shutil.copy(file, trainx_path)

for file in trainy:
    if (trainy_path / file.name).exists():
        continue
    shutil.copy(file, trainy_path)

for file in testx:
    if (testx_path / file.name).exists():
        continue
    shutil.copy(file, testx_path)
for file in testy:
    if (testy_path / file.name).exists():
        continue
    shutil.copy(file, testy_path)
for file in valx:
    if (valx_path / file.name).exists():
        continue
    shutil.copy(file, valx_path)
for file in valy:
    if (valy_path / file.name).exists():
        continue
    shutil.copy(file, valy_path)

# %% [markdown]
# # model training

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s.pt")


if __name__ == "__main__":
    # Train the model
    train_results = model.train(
        data="../configs/data.yaml",  # path to dataset YAML
        epochs=1000,  # number of training epochs
        imgsz=640,  # training image size
        device="cpu",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
        # save_period = 100,  # directory to save results
        # save_best = True,  # save the best model
        # workers = 2
        save=True,
        save_period=100,
        project="../models/v1",
    )

    path = model.export(format="torchscript")  # return path to exported model
    #
    # path of the exported model is returned
# Out:
# New https://pypi.org/project/ultralytics/8.3.114 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.110 🚀 Python-3.11.12 torch-2.6.0 CPU (Apple M1)
# engine/trainer: task=detect, mode=train, model=yolo11s.pt, data=../configs/data.yaml, epochs=1000, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=100, cache=False, device=cpu, workers=8, project=../models/v1, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=../models/v1/train3
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.3±0.0 ms, read: 1524.6±0.0 MB/s, size: 1201.3 KB)
# train: Scanning /Users/nischal/projects/CocoDet/data/test_dataset/train/labels... 1 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1/1 [00:00<00:00,  9.11it/s]
# train: New cache created: /Users/nischal/projects/CocoDet/data/test_dataset/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1567.5±0.0 MB/s, size: 1201.3 KB)
# val: Scanning /Users/nischal/projects/CocoDet/data/test_dataset/val/labels... 1 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1/1 [00:00<00:00, 1022.50it/s]
# val: New cache created: /Users/nischal/projects/CocoDet/data/test_dataset/val/labels.cache
# Plotting labels to ../models/v1/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to ../models/v1/train3
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      1/1000         0G      6.461      5.736      2.612        419        640: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]
#                    all          1        300          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      2/1000         0G      6.333      3.345      3.186        366        640: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
#                    all          1        300          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      3/1000         0G      6.506      4.444      2.679        810        640: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
#                    all          1        300          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000         0G      6.291      3.291      2.714        642        640: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
#                    all          1        300          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000         0G      6.305      3.778       2.56        488        640: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
#                    all          1        300          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      6/1000         0G       6.09      3.062      2.276        668        640: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
#                    all          1        300          0          0          0          0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       4 model = YOLO("yolo11s.pt")
#       7 if __name__ == "__main__":
#       8     # Train the model
# ----> 9     train_results = model.train(
#      10         data="../configs/data.yaml",  # path to dataset YAML
#      11         epochs=1000,  # number of training epochs
#      12         imgsz=640,  # training image size
#      13         device='cpu',  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
#      14         # save_period = 100,  # directory to save results
#      15         # save_best = True,  # save the best model
#      16         # workers = 2
#      17         save = True,
#      18         save_period = 100,
#      19         project = "../models/v1",
#      20
#      21     )
#      24     path = model.export(format="torchscript")  # return path to exported model
#      25     #
#      26     # path of the exported model is returned
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/ultralytics/engine/model.py:791, in Model.train(self, trainer, **kwargs)
#     788     self.model = self.trainer.model
#     790 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 791 self.trainer.train()
#     792 # Update model and cfg after training
#     793 if RANK in {-1, 0}:
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/ultralytics/engine/trainer.py:211, in BaseTrainer.train(self)
#     208         ddp_cleanup(self, str(file))
#     210 else:
# --> 211     self._do_train(world_size)
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/ultralytics/engine/trainer.py:446, in BaseTrainer._do_train(self, world_size)
#     444     # Save model
#     445     if self.args.save or final_epoch:
# --> 446         self.save_model()
#     447         self.run_callbacks("on_model_save")
#     449 # Scheduler
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/ultralytics/engine/trainer.py:537, in BaseTrainer.save_model(self)
#     535 # Serialize ckpt to a byte buffer once (faster than repeated torch.save() calls)
#     536 buffer = io.BytesIO()
# --> 537 torch.save(
#     538     {
#     539         "epoch": self.epoch,
#     540         "best_fitness": self.best_fitness,
#     541         "model": None,  # resume and final checkpoints derive from EMA
#     542         "ema": deepcopy(self.ema.ema).half(),
#     543         "updates": self.ema.updates,
#     544         "optimizer": convert_optimizer_state_dict_to_fp16(deepcopy(self.optimizer.state_dict())),
#     545         "train_args": vars(self.args),  # save as dict
#     546         "train_metrics": {**self.metrics, **{"fitness": self.fitness}},
#     547         "train_results": self.read_results_csv(),
#     548         "date": datetime.now().isoformat(),
#     549         "version": __version__,
#     550         "license": "AGPL-3.0 (https://ultralytics.com/license)",
#     551         "docs": "https://docs.ultralytics.com",
#     552     },
#     553     buffer,
#     554 )
#     555 serialized_ckpt = buffer.getvalue()  # get the serialized content to save
#     557 # Save checkpoints
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/ultralytics/utils/patches.py:130, in torch_save(*args, **kwargs)
#     128 for i in range(4):  # 3 retries
#     129     try:
# --> 130         return _torch_save(*args, **kwargs)
#     131     except RuntimeError as e:  # unable to save, possibly waiting for device to flush or antivirus scan
#     132         if i == 3:
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/torch/serialization.py:944, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     942 if _use_new_zipfile_serialization:
#     943     with _open_zipfile_writer(f) as opened_zipfile:
# --> 944         _save(
#     945             obj,
#     946             opened_zipfile,
#     947             pickle_module,
#     948             pickle_protocol,
#     949             _disable_byteorder_record,
#     950         )
#     951         return
#     952 else:
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/torch/serialization.py:1190, in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1187         return persistent_id(obj)
#    1189 pickler = PyTorchPickler(data_buf, protocol=pickle_protocol)
# -> 1190 pickler.dump(obj)
#    1191 data_value = data_buf.getvalue()
#    1192 zip_file.write_record("data.pkl", data_value, len(data_value))
#
# File ~/projects/CocoDet/env/lib/python3.11/site-packages/torch/serialization.py:1186, in _save.<locals>.PyTorchPickler.persistent_id(self, obj)
#    1185 class PyTorchPickler(pickle_module.Pickler):  # type: ignore[name-defined]
# -> 1186     def persistent_id(self, obj):
#    1187         return persistent_id(obj)
#
# KeyboardInterrupt:

# %% [markdown]
# # model testing

# %%
from shapely.geometry import Point


def txt_to_shp(txt_dir, img_dir, shp_dir):
    for i in glob.glob(os.path.join(txt_dir, "*.txt")):
        file_name = os.path.splitext(os.path.basename(i))[0]

        with rio.open(os.path.join(img_dir, f"{file_name}.tif")) as src:
            # profile = src.profile
            bounds = src.bounds
            crs = src.crs
            # raster_extent = box(*bounds)
            top_left_corner = (bounds.left, bounds.top)
            bottom_right_corner = (bounds.right, bounds.bottom)

        df = pd.read_csv(i, delimiter=" ", names=["class", "x", "y", "width", "height"])

        df["x"] = (
            df["x"] * (bottom_right_corner[0] - top_left_corner[0]) + top_left_corner[0]
        )
        df["y"] = top_left_corner[1] - df["y"] * (
            top_left_corner[1] - bottom_right_corner[1]
        )

        df["centroid"] = [Point(x, y) for x, y in zip(df.x, df.y)]

        gdf = gpd.GeoDataFrame(geometry=df["centroid"], crs=crs)

        # gdf['geometry'] = gdf.geometry.apply(lambda geom: point_to_bbox(geom, buffer_x, buffer_y))
        gdf.to_file(os.path.join(shp_dir, f"{file_name}.shp"), driver="ESRI Shapefile")

# %%
def concat(shp_dir, output_dir):
    df = None
    for i in glob.glob(os.path.join(shp_dir, "*.shp")):
        df_curr = gpd.read_file(i)
        if df is None:
            df = df_curr
        else:
            df = pd.concat([df, df_curr], ignore_index=True)

    gdf = gpd.GeoDataFrame(df)
    gdf.to_file(os.path.join(output_dir, "prediction.shp"), driver="ESRI Shapefile")

# %%
import folium
import geopandas as gpd

# %%
# tile = folium.TileLayer(
#             tiles = 'http://mt0.google.com/vt/lyrs=s&hl=en&x={x}&y={y}&z={z}',
#             attr = 'Google Satellite',
#             name = 'Satellite',
#             overlay = False,
#             control = True)
m = folium.Map(location=[23.437, 94.012], zoom_start=4)
folium.LayerControl().add_to(m)
gdf = gpd.read_file("../tmp1c2h0gp3/image.shp").to_crs(epsg=4326)
folium.GeoJson(gdf).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e222c5aedb52693bd037ba6346bcd35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e222c5aedb52693bd037ba6346bcd35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e222c5aedb52693bd037ba6346bcd35 = L.map(
#                 &quot;map_5e222c5aedb52693bd037ba6346bcd35&quot;,
#                 {
#                     center: [23.437, 94.012],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecefd62ac1e359540f681357bcc4f48b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ecefd62ac1e359540f681357bcc4f48b.addTo(map_5e222c5aedb52693bd037ba6346bcd35);
#
#
#             var layer_control_aec24454d58940e7fa32497457b1ef13_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ecefd62ac1e359540f681357bcc4f48b,
#                 },
#                 overlays :  {
#                     &quot;macro_element_680289ff9ccaab41b03a1f9c1b7d5ce5&quot; : geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5,
#                 },
#             };
#             let layer_control_aec24454d58940e7fa32497457b1ef13 = L.control.layers(
#                 layer_control_aec24454d58940e7fa32497457b1ef13_layers.base_layers,
#                 layer_control_aec24454d58940e7fa32497457b1ef13_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5e222c5aedb52693bd037ba6346bcd35);
#
#
#
#
#         function geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5 = L.geoJson(null, {
#                 onEachFeature: geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5_add (data) {
#             geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5
#                 .addData(data);
#         }
#             geo_json_680289ff9ccaab41b03a1f9c1b7d5ce5_add({&quot;bbox&quot;: [80.22949924214713, 7.7135851093036845, 80.231551340787, 7.7156439465919675], &quot;features&quot;: [{&quot;bbox&quot;: [80.23056881875299, 7.713944626546413, 80.23056881875299, 7.713944626546413], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23056881875299, 7.713944626546413], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;FID&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23072703213599, 7.714315778302937, 80.23072703213599, 7.714315778302937], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23072703213599, 7.714315778302937], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;FID&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23085069732097, 7.714838121939649, 80.23085069732097, 7.714838121939649], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23085069732097, 7.714838121939649], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;FID&quot;: 2}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23003105102798, 7.714501076322017, 80.23003105102798, 7.714501076322017], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23003105102798, 7.714501076322017], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;FID&quot;: 3}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.22969109709358, 7.714347520000389, 80.22969109709358, 7.714347520000389], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.22969109709358, 7.714347520000389], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;FID&quot;: 4}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23018470431599, 7.715167866475941, 80.23018470431599, 7.715167866475941], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23018470431599, 7.715167866475941], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;FID&quot;: 5}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23072990384799, 7.7148162905325375, 80.23072990384799, 7.7148162905325375], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23072990384799, 7.7148162905325375], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;FID&quot;: 6}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23014084183697, 7.714778380528238, 80.23014084183697, 7.714778380528238], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23014084183697, 7.714778380528238], &q

# %%
import folium
import geopandas as gpd

# Create base map with no default tiles
m = folium.Map(location=[23.437, 94.012], zoom_start=6, tiles=None)

# Add custom Google Satellite TileLayer
tile = folium.TileLayer(
    tiles="http://mt0.google.com/vt/lyrs=s&hl=en&x={x}&y={y}&z={z}",
    attr="Google Satellite",
    name="Satellite",
    overlay=False,
    control=True,
)
tile.add_to(m)

# Read and add GeoJSON layer
gdf = gpd.read_file("../tmp1c2h0gp3/image.shp").to_crs(epsg=4326)
folium.GeoJson(
    gdf,
    name="GeoData",
    marker=folium.Circle(
        radius=4,
        fill_color="orange",
        fill_opacity=0.1,
        color="red",
        weight=1,
    ),
    highlight_function=lambda x: {"fillOpacity": 0.8},
    zoom_on_click=True,
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)

# Show the map (in Jupyter Notebook, just output `m`)
bounds = gdf.total_bounds  # [minx, miny, maxx, maxy]
m.fit_bounds([[bounds[1], bounds[0]], [bounds[3], bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b27c310f98428bf774c26384848e1825 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b27c310f98428bf774c26384848e1825&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b27c310f98428bf774c26384848e1825 = L.map(
#                 &quot;map_b27c310f98428bf774c26384848e1825&quot;,
#                 {
#                     center: [23.437, 94.012],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc4a35a43606f57d647409f15ce6ac9f = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=s\u0026hl=en\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Satellite&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc4a35a43606f57d647409f15ce6ac9f.addTo(map_b27c310f98428bf774c26384848e1825);
#
#
#         function geo_json_6581f74cda84e9f677829be0feea8293_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8};
#             }
#         }
#         function geo_json_6581f74cda84e9f677829be0feea8293_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1};
#
#             return new L.circle(latlng, opts)
#         }
#
#         function geo_json_6581f74cda84e9f677829be0feea8293_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6581f74cda84e9f677829be0feea8293.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6581f74cda84e9f677829be0feea8293_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#                 click: function(e) {
#                     if (typeof e.target.getBounds === &#x27;function&#x27;) {
#                         map_b27c310f98428bf774c26384848e1825.fitBounds(e.target.getBounds());
#                     }
#                     else if (typeof e.target.getLatLng === &#x27;function&#x27;){
#                         let zoom = map_b27c310f98428bf774c26384848e1825.getZoom()
#                         zoom = zoom &gt; 12 ? zoom : zoom + 1
#                         map_b27c310f98428bf774c26384848e1825.flyTo(e.target.getLatLng(), zoom)
#                     }
#                 }
#             });
#         };
#         var geo_json_6581f74cda84e9f677829be0feea8293 = L.geoJson(null, {
#                 onEachFeature: geo_json_6581f74cda84e9f677829be0feea8293_onEachFeature,
#
#                 pointToLayer: geo_json_6581f74cda84e9f677829be0feea8293_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6581f74cda84e9f677829be0feea8293_add (data) {
#             geo_json_6581f74cda84e9f677829be0feea8293
#                 .addData(data);
#         }
#             geo_json_6581f74cda84e9f677829be0feea8293_add({&quot;bbox&quot;: [80.22949924214713, 7.7135851093036845, 80.231551340787, 7.7156439465919675], &quot;features&quot;: [{&quot;bbox&quot;: [80.23056881875299, 7.713944626546413, 80.23056881875299, 7.713944626546413], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23056881875299, 7.713944626546413], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;FID&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23072703213599, 7.714315778302937, 80.23072703213599, 7.714315778302937], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23072703213599, 7.714315778302937], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;FID&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23085069732097, 7.714838121939649, 80.23085069732097, 7.714838121939649], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23085069732097, 7.714838121939649], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;FID&quot;: 2}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80.23003105102798, 7.714501076322017, 80.23003105102798, 7.714501076322017], &quot;geometry&quot;: {&quot;coordinates&quot;: [80.23003105102798, 7.714501076322017], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;FID&quot;: 3}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [80

# %%
import geopandas as gpd

gdf = gpd.read_file("../data/preds.shp")

# %%
# def buffer_download(centroid):
centroids = gdf
# centroid.to_crs(epsg=4326)
centroids
# Out:
#           minx      miny       maxx      maxy
# 0    80.020237  7.552125  80.020237  7.552125
# 1    80.020632  7.552015  80.020632  7.552015
# 2    80.020048  7.551602  80.020048  7.551602
# 3    80.020156  7.552038  80.020156  7.552038
# 4    80.020030  7.552518  80.020030  7.552518
# ..         ...       ...        ...       ...
# 503  80.021773  7.556601  80.021773  7.556601
# 504  80.022078  7.556532  80.022078  7.556532
# 505  80.022563  7.556669  80.022563  7.556669
# 506  80.021081  7.556585  80.021081  7.556585
# 507  80.022204  7.556528  80.022204  7.556528
#
# [508 rows x 4 columns]

# %%
centroid_buffer = gdf.to_crs(epsg=3857).buffer(15, cap_style="square")

# %%
buffer = centroid_buffer.to_crs(4326)

# %%
import sys

sys.path.append(os.path.abspath("../"))
from src.download import TMStoGeoTIFF

# %%
buffer.bounds.to_numpy().tolist()[0]
# Out:
# [80.0201019293402, 7.551991471294963, 80.02037142392544, 7.552258628204508]

# %%
ras = TMStoGeoTIFF("img1.tiff", bbox=buffer.bounds.to_numpy().tolist()[0])

# %%
ras.download()

# %%
centroids.to_crs(epsg=3857)
buffer = [-15, 15, 15, -15]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pm/w0ypms2d7h18t0lc86kv9cbc0000gn/T/ipykernel_15692/2996055750.py in ?()
# ----> 1 centroids.to_crs(epsg=3857)
#       2 buffer = [-15, 15, 15, -15]
#
# ~/projects/CocoDet/env/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_crs'

# %%
import sys

# sys.path.append("..")
# from src.database.connection import engine
from sqlmodel import create_engine
import geopandas as gpd
from pathlib import Path
# def get_bbox_count():

engine = create_engine("postgresql://postgres:postgres@localhost/coconut_db")
query = "SELECT * FROM pred"
pred = gpd.read_postgis(query, con=engine, crs=3857, geom_col="geometry").to_crs(4326)
cnt = len(pred)

country_shp = Path("..", "data", "countries", "world-administrative-boundaries.shp")
country = gpd.read_file(country_shp)

inter = pred.sjoin(country, how="left", predicate="within")


# inter.plot()
# plt.show()

# print(inter)
# return pred, cnt.
inter.groupby("name").count()["id"]
# Out:
# name
# Sri Lanka    9619
# Name: id, dtype: int64

# %%
pred.centroid
# Out:
# /var/folders/pm/w0ypms2d7h18t0lc86kv9cbc0000gn/T/ipykernel_46072/939048266.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   pred.centroid
# 0       POINT (80.01294 7.55432)
# 1       POINT (80.01293 7.55438)
# 2       POINT (80.01273 7.55388)
# 3       POINT (80.01292 7.55502)
# 4        POINT (80.0125 7.55401)
#                   ...
# 9614    POINT (80.01177 7.55373)
# 9615     POINT (80.01155 7.5535)
# 9616    POINT (80.01229 7.55317)
# 9617    POINT (80.01248 7.55362)
# 9618    POINT (80.01189 7.55368)
# Length: 9619, dtype: geometry

# %%
len(pred["id_bbox"].unique())
# Out:
# 53

# %%
# data = (
#     np.random.normal(size=(1, 3)) * np.array([[1, 1, 1]]) + np.array([[48, 5, 1]])
# ).tolist()
# data

# %%
pred["latitude"], pred["longitude"] = pred.geometry.x, pred.geometry.y
heat_data = pred[["longitude", "latitude"]].values.tolist()
# pred
# heat_data

# %%
import folium
from folium.plugins import HeatMap

m = folium.Map(zoom_start=3)

HeatMap(heat_data, radius=10, blur=10).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de6ef88207e4848983d397963a9be599 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de6ef88207e4848983d397963a9be599&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de6ef88207e4848983d397963a9be599 = L.map(
#                 &quot;map_de6ef88207e4848983d397963a9be599&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce5c20c3dacdbc507519e77008bd7548 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce5c20c3dacdbc507519e77008bd7548.addTo(map_de6ef88207e4848983d397963a9be599);
#
#
#             var heat_map_5cb097db09576d4515dc775ed6cbc670 = L.heatLayer(
#                 [[7.554315730875732, 80.01294235652577], [7.554377510593435, 80.01293337337293], [7.553875480559565, 80.01272676085759], [7.555015900492383, 80.01292439022009], [7.554010171601521, 80.01250218203656], [7.554702549683402, 80.01291540706724], [7.5543090519868015, 80.01300523859565], [7.5540190767928985, 80.01256506410644], [7.554376397445446, 80.01287049130303], [7.553808135022844, 80.01268184509338], [7.553772514238843, 80.01236743474394], [7.554365265965402, 80.01242133366098], [7.554376954019441, 80.01298727228998], [7.554315174301658, 80.01